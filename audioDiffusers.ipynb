# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/class2023Spring/blob/main/audioDiffusers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Make sure that hardware accelerator in Runtime type is set to GPU.
# !pip install diffusers transformers accelerate safetensors
import torch

from diffusers import AudioLDMPipeline
import torch

repo_id = "cvssp/audioldm"
pipe = AudioLDMPipeline.from_pretrained(repo_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

prompt = "Techno music with a strong, upbeat tempo and high melodic riffs"
audio = pipe(prompt, num_inference_steps=10, audio_length_in_s=5.0).audios[0]
# Out:
# unet/diffusion_pytorch_model.safetensors not found
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
import scipy
scipy.io.wavfile.write("techno.wav", rate=16000, data=audio)

from IPython.display import Audio
Audio(audio, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
